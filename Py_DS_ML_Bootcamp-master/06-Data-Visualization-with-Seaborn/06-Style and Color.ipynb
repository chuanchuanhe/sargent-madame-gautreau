# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # Style and Color
#
# We've shown a few times how to control figure aesthetics in seaborn, but let's now go over it formally:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## Styles
#
# You can set particular styles:

# %%
sns.countplot(x='sex',data=tips)

plt.show()

# %%
sns.set_style('white')
sns.countplot(x='sex',data=tips)

plt.show()

# %%
sns.set_style('ticks')
sns.countplot(x='sex',data=tips,palette='deep')

plt.show()
# Out:
# C:\Users\chuan\AppData\Local\Temp\ipykernel_60348\1895886141.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex',data=tips,palette='deep')

# %%
sns.set_style('whitegrid')
sns.countplot(x='sex',data=tips,palette='deep')

plt.show()
# Out:
# C:\Users\chuan\AppData\Local\Temp\ipykernel_60348\4163758005.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex',data=tips,palette='deep')

# %%
sns.set_style('darkgrid')
sns.countplot(x='sex',data=tips,palette='deep')

plt.show()
# Out:
# C:\Users\chuan\AppData\Local\Temp\ipykernel_60348\2014929109.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex',data=tips,palette='deep')

# %% [markdown]
# ## Spine Removal

# %%
sns.set_style('ticks')
sns.countplot(x='sex',data=tips)
sns.despine()

plt.show()

# %%
sns.countplot(x='sex',data=tips)
sns.despine(left=True, bottom=True)

plt.show()

# %% [markdown]
# ## Size and Aspect

# %% [markdown]
# You can use matplotlib's **plt.figure(figsize=(width,height) ** to change the size of most seaborn plots.
#
# You can control the size and aspect ratio of most seaborn grid plots by passing in parameters: size, and aspect. For example:

# %%
# Non Grid Plot
plt.figure(figsize=(12,3))
sns.countplot(x='sex',data=tips)

plt.show()

# %%
# Grid Type Plot
sns.lmplot(x='total_bill',y='tip',height=3,aspect=4,data=tips)

plt.show()

# %% [markdown]
# ## Scale and Context
#
# The set_context() allows you to override default parameters:

# %%
sns.set_context('poster',font_scale=1)
sns.countplot(x='sex',data=tips,palette='coolwarm')

plt.show()
# Out:
# C:\Users\chuan\AppData\Local\Temp\ipykernel_60348\2127857437.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex',data=tips,palette='coolwarm')

# %%
sns.set_context('notebook')  #default
sns.countplot(x='sex',data=tips,palette='coolwarm')

plt.show()
# Out:
# C:\Users\chuan\AppData\Local\Temp\ipykernel_60348\1242836407.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='sex',data=tips,palette='coolwarm')

# %% [markdown]
# Check out the documentation page for more info on these topics:
# https://stanford.edu/~mwaskom/software/seaborn/tutorial/aesthetics.html

# %% [markdown]
# # Great Job!
